# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gymnasium as gym
import popgym  # important: this triggers registration

full_envs_list = [x for x in gym.envs.registry.keys() if "popgym" in x.lower()]

# %%
[elem for elem in full_envs_list if "PositionOnlyCartPole" in elem]
# Out:
# ['popgym-PositionOnlyCartPoleEasy-v0',
#  'popgym-NoisyPositionOnlyCartPoleEasy-v0',
#  'popgym-PositionOnlyCartPoleMedium-v0',
#  'popgym-NoisyPositionOnlyCartPoleMedium-v0',
#  'popgym-PositionOnlyCartPoleHard-v0',
#  'popgym-NoisyPositionOnlyCartPoleHard-v0']

# %%
[elem for elem in full_envs_list if "Easy" in elem]
# Out:
# ['popgym-AutoencodeEasy-v0',
#  'popgym-RepeatPreviousEasy-v0',
#  'popgym-RepeatFirstEasy-v0',
#  'popgym-CountRecallEasy-v0',
#  'popgym-PositionOnlyCartPoleEasy-v0',
#  'popgym-PositionOnlyPendulumEasy-v0',
#  'popgym-VelocityOnlyCartpoleEasy-v0',
#  'popgym-NoisyPositionOnlyCartPoleEasy-v0',
#  'popgym-NoisyPositionOnlyPendulumEasy-v0',
#  'popgym-MultiarmedBanditEasy-v0',
#  'popgym-HigherLowerEasy-v0',
#  'popgym-BattleshipEasy-v0',
#  'popgym-ConcentrationEasy-v0',
#  'popgym-MineSweeperEasy-v0',
#  'popgym-LabyrinthExploreEasy-v0',
#  'popgym-LabyrinthEscapeEasy-v0']
